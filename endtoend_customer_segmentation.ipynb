# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("F:/Downloads/Customer Data.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())

# %%
df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['CUST_ID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(30,15))
for i,col in enumerate(df.columns):
    if df[col].dtype !='object':
        ax=plt.subplot(9,2,i+1)
        sns.kdeplot(df[col],ax=ax)

# %%
plt.figure(figsize=(30,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
df_scalar=scaler.fit_transform(df)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
pcavalues=pca.fit_transform(df_scalar)

# %%
df_pca=pd.DataFrame(pcavalues,columns=['PCA1','PCA2','PCA3'])

# %%
from sklearn.cluster import KMeans

# %%
inertia=[]
for i in range(1,8):
    km=KMeans(n_clusters=i)
    km.fit_predict(df_pca)
    inertia.append(km.inertia_)
plt.plot(range(1,8),inertia)
plt.show()

# %%
km=KMeans(n_clusters=4)
cluster=km.fit_transform(df)

# %%
km.labels_
# Out:
# array([0, 1, 3, ..., 0, 0, 0])

# %%
df_pca
# Out:
#           PCA1      PCA2      PCA3
# 0    -1.682220 -1.076452  0.488574
# 1    -1.138296  2.506480  0.601511
# 2     0.969685 -0.383521  0.102050
# 3    -0.873628  0.043166  1.460334
# 4    -1.599434 -0.688582  0.365101
# ...        ...       ...       ...
# 8945 -0.359629 -2.016148 -0.995411
# 8946 -0.564369 -1.639126 -1.290268
# 8947 -0.926204 -1.810788 -0.474761
# 8948 -2.336552 -0.657968  0.974753
# 8949 -0.556422 -0.400465  1.015034
#
# [8950 rows x 3 columns]

# %%
clu_df=pd.concat([df_pca,pd.DataFrame({'cluster':km.labels_})],axis=1)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(20, 13))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(clu_df['PCA1'], clu_df['PCA2'], clu_df['PCA3'], c=clu_df['cluster'], cmap='viridis')

# Set labels
ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_zlabel('PCA3')

# Add colorbar
plt.colorbar(scatter, label='cluster')

plt.show()

# %%
cluster_centers = pd.DataFrame(data=km.cluster_centers_,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0   841.631112          0.853097    513.167101       249.886563
# 1  6189.800122          0.974480   1098.189778       596.760183
# 2  4796.387514          0.905372  11317.598083      8113.631167
# 3  1650.534896          0.903090   1641.625902      1043.103791
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             263.571248   517.882105            0.451480
# 1             501.516884  4630.257633            0.391818
# 2            3204.150250  4938.088679            0.762992
# 3             598.921235   706.443983            0.603731
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.132703                         0.346084
# 1                   0.187891                         0.296597
# 2                   0.624497                         0.611411
# 3                   0.356191                         0.418896
#
# ...

# %%
# Creating a target column "Cluster" for storing the cluster segment
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':km.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1      3202.467416           0.909091       0.00              0.00
# 15     6886.213231           1.000000    1611.70              0.00
# 23     3800.151377           0.818182    4248.35           3454.56
# 28     7152.864372           1.000000     387.05            204.55
# 30    12136.219960           1.000000    3038.01           1013.20
# ...            ...                ...        ...               ...
# 8705   7302.672686           1.000000       0.00              0.00
# 8724   3002.791004           1.000000    2463.00           2463.00
# 8813   3335.053583           0.700000       0.00              0.00
# 8857   2330.222764           1.000000    1320.00              0.00
# 8941   5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 39     1411.602230           0.454545     963.24            963.24
# 71     2990.422186           0.909091    4523.27           1664.09
# 125    2392.917738           1.000000   12462.44          12462.44
# 138   19043.138560           1.000000   22009.92           9449.07
# 153   13673.079610           1.000000    9792.23           3959.81
# ...            ...                ...        ...               ...
# 7254   4530.205197           1.000000    1750.66            643.18
# 7277    561.003319           1.000000   11577.00          10975.00
# 7426     36.979201           0.181818       0.00              0.00
# 7553   2017.391656           1.000000   12024.37          11224.10
# 7645   7081.171387           1.000000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 39                      0.00   6173.682877             0.083333
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"]==3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 6      627.260806           1.000000    7091.01           6402.63
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8745  1000.814822           0.285714       0.00              0.00
# 8748  1042.816735           0.625000    3950.00           3950.00
# 8769   116.581583           0.818182    1045.14            227.14
# 8774  2585.246439           0.909091     338.00              0.00
# 8839  3271.424058           0.888889    1173.28              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00      0.000000             1.000000
# ...

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
#Split Dataset
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#Decision_Tree
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
#Confusion_Matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[239], line 2
#       1 #Confusion_Matrix
# ----> 2 print(metrics.confusion_matrix(y_test, y_pred))
#       3 print(classification_report(y_test, y_pred))
#
# NameError: name 'metrics' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[241], line 2
#       1 #Confusion_Matrix
# ----> 2 print(metrics.confusion_matrix(y_test, y_pred))
#       3 print(classification_report(y_test, y_pred))
#
# NameError: name 'metrics' is not defined

# %%
import pickle
pickle.dump(model,open('model_pickle_customerseg','wb'))
